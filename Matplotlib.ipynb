# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.0

# %% [markdown]
# Matplotlib
#
# a low level graph plotting library
#
# open source and we can use it freely
#
# pip install matplotlib
#
# import matplotlib

# %%
#

import matplotlib.pyplot as plt

# %%
#draw  a line a diagram
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,6])
ypoints= np.array([0,250])
plt.plot(xpoints,ypoints)
plt.show()

# %%
#plotting without line
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,6])
ypoints= np.array([0,250])
plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
#multiple points
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints= np.array([3,8,1,15])
plt.plot(xpoints,ypoints)
plt.show()

# %%
#defult x point
import numpy as np
import matplotlib.pyplot as plt
ypoints= np.array([3,8,1,15,4,5])
plt.plot(ypoints,marker='D')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
ypoints= np.array([3,8,1,15,4,5])
plt.plot(ypoints,'o:g')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
ypoints= np.array([3,8,1,15,4,5])
plt.plot(ypoints,marker='o',ms=15 ,mec='r')# marker edge color
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.title("sport watch data")
plt.xlabel("avrage burnage")
plt.ylabel("calories burnage")
plt.plot(x,y)
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot1
x=np.array([0,1,2,3,4])
y=np.array([3,4,5,6,10])
plt.subplot(1,2,1)
plt.plot(x,y)
#plot 2
x=np.array([0,1,2,3,4])
y=np.array([3,2,5,8,0])
plt.subplot(1,2,2)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt #(row ,cloumn ,subploat pocition)
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 2)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])

#day three the age and speed of 10 cars:

x = np.array([5,70,8,71,2,17,20,9,4,11])
y = np.array([9,8,8,8,11,8,10,8,94,78,])

plt.scatter(x, y)
plt.scatter(x, y)
plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(['A','B','C','D'])
y= np.array([3,8,1,10])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(['A','B','C','D'])
y= np.array([3,8,1,10])
plt.barh(x,y,color='green')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(['A','B','C','D'])
y= np.array([3,8,1,10])
plt.bar(x,y,color='green',width=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y= np.array([35,25,25,5])
plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y= np.array([35,25,25,5])
mylabels=['apple','dates','banana','kiwi']
plt.pie(y,labels=mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y= np.array([35,25,25,5])
mylabels=['apple','dates','banana','kiwi']
myexpolad=[0.2,0.1,0,0]
plt.pie(y,labels=mylabels, explode=myexpolad)
plt.legend()
plt.show()

# %%
import pandas as pd

# %%
info={
    'names':['krusha','milin','malav','ishani'],
    'age':[29,28,24,23]
}
print(info)
# Out:
# {'names': ['krusha', 'milin', 'malav', 'ishani'], 'age': [29, 28, 24, 23]}

# %%
df=pd.DataFrame(info)
print(df)
# Out:
#     names  age
# 0  krusha   29
# 1   milin   28
# 2   malav   24
# 3  ishani   23

# %%
info2={
    'names':['krupa','milind'],
    'age':[29,28]
}
print(info2)
# Out:
# {'names': ['krupa', 'milind'], 'age': [29, 28]}

# %%
df1=pd.DataFrame(info2)
print(df1)
# Out:
#     names  age
# 0   krupa   29
# 1  milind   28

# %%
df=df._append(df1,ignore_index=True)
print(df)
# Out:
#     names  age
# 0  krusha   29
# 1   milin   28
# 2   malav   24
# 3  ishani   23
# 4  krusha   29
# 5   milin   28
# 6   krupa   29
# 7  milind   28
# 8   krupa   29
# 9  milind   28

# %%
df=df._append(pd.DataFrame([['riya',30]],columns=df.columns),ignore_index=True)
print(df)
# Out:
#      names  age
# 0   krusha   29
# 1    milin   28
# 2    malav   24
# 3   ishani   23
# 4   krusha   29
# 5    milin   28
# 6    krupa   29
# 7   milind   28
# 8    krupa   29
# 9   milind   28
# 10    riya   30

# %%
df=df._append(pd.DataFrame([{'names':'bansari','age':'29'}],columns=df.columns),ignore_index=True)
print(df)
# Out:
#       names age
# 0    krusha  29
# 1     milin  28
# 2     malav  24
# 3    ishani  23
# 4    krusha  29
# 5     milin  28
# 6     krupa  29
# 7    milind  28
# 8     krupa  29
# 9    milind  28
# 10     riya  30
# 11      NaN  29
# 12  bansari  29

# %%
df.drop(index=[5,2],inplace=True,axis=0)
print(df)
# Out:
#       names age
# 0    krusha  29
# 1     milin  28
# 3    ishani  23
# 4    krusha  29
# 6     krupa  29
# 7    milind  28
# 8     krupa  29
# 9    milind  28
# 10     riya  30
# 11      NaN  29
# 12  bansari  29

# %%
df.drop(['names'],inplace=True,axis=1)
print(df)
# Out:
#    age
# 0   29
# 1   28
# 3   23
# 4   29
# 6   29
# 7   28
# 8   29
# 9   28
# 10  30
# 11  29
# 12  29

# %%
#read data from csv
from google.colab import files
uploaded=files.upload()
loan=pd.read_csv('loan.csv')
print(loan)
# Out:
#      <input type="file" id="files-af41dacf-7043-42b5-b153-dcaff84f5bbf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af41dacf-7043-42b5-b153-dcaff84f5bbf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
loan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
loan.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
loan.set_index('Loan_ID',inplace = True)
loan.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# LP001003             4583             1508.0       128.0             360.0
# LP001005             3000                0.0        66.0             360.0
# LP001006             2583             2358.0       120.0             360.0
# LP001008             6000                0.0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# ...

# %%
loan.iloc[0]
# Out:
# Gender                   Male
# Married                    No
# Dependents                  0
# Education            Graduate
# Self_Employed              No
# ApplicantIncome          5849
# CoapplicantIncome         0.0
# LoanAmount                NaN
# Loan_Amount_Term        360.0
# Credit_History            1.0
# Property_Area           Urban
# Loan_Status                 Y
# Name: LP001002, dtype: object

# %%
loan.loc['LP001003']
# Out:
# Gender                   Male
# Married                   Yes
# Dependents                  1
# Education            Graduate
# Self_Employed              No
# ApplicantIncome          4583
# CoapplicantIncome      1508.0
# LoanAmount              128.0
# Loan_Amount_Term        360.0
# Credit_History            1.0
# Property_Area           Rural
# Loan_Status                 N
# Name: LP001003, dtype: object

# %%
p_area=loan['Property_Area'].nunique()
print(p_area)
# Out:
# 3

# %%
p_area=loan['Gender'].nunique()
print(p_area)
# Out:
# 2

# %%
dep=loan['Dependents'].nunique()#total no of unique elements
print(dep)
# Out:
# 4

# %%
dep=loan['Dependents'].unique()#total no of unique elements
print(dep)
# Out:
# ['0' '1' '2' '3+' nan]

# %%
print(loan['Dependents'].value_counts())
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
print(loan['Property_Area'].value_counts())
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
print(pd.isnull(loan['Dependents']).sum()) #count null in column
# Out:
# 15

# %%
print(pd.isnull(loan['Dependents']).sum)
# Out:
# <bound method Series.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# Name: Dependents, Length: 614, dtype: bool>

# %%
cred=loan[loan['Credit_History']==1]
cred
# Out:
#           Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002    Male      No          0      Graduate            No
# LP001003    Male     Yes          1      Graduate            No
# LP001005    Male     Yes          0      Graduate           Yes
# LP001006    Male     Yes          0  Not Graduate            No
# LP001008    Male      No          0      Graduate            No
# ...          ...     ...        ...           ...           ...
# LP002974    Male     Yes          0      Graduate            No
# LP002978  Female      No          0      Graduate            No
# LP002979    Male     Yes         3+      Graduate            No
# LP002983    Male     Yes          1      Graduate            No
# LP002984    Male     Yes          2      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# ...

# %%
l_h=loan[loan['Married']=='Yes']['Education'].value_counts()
print(l_h)
# Out:
# Education
# Graduate        309
# Not Graduate     89
# Name: count, dtype: int64

# %%
loan['Loan_Amount_Term'].idxmax()
# Out:
# 75

# %%
loan['Loan_Amount_Term'].idxmin()
# Out:
# 497

# %%
import numpy as np

# %%
np.min(loan['Loan_Amount_Term'])
# Out:
# 12.0

# %%
np.max(loan['Loan_Amount_Term'])
# Out:
# 480.0

# %%
np.mean(loan['Loan_Amount_Term'])
# Out:
# np.float64(342.0)

# %%
loan.groupby('Gender')[['Loan_Amount_Term']].mean()
# Out:
#         Loan_Amount_Term
# Gender
# Female        352.293578
# Male          339.665272

# %%
loan.groupby('Dependents')[['Loan_Amount_Term']].mean()
# Out:
#             Loan_Amount_Term
# Dependents
# 0                 348.107784
# 1                 329.346535
# 2                 340.871287
# 3+                325.200000

# %%
 loan.groupby('Gender')[['Loan_Amount_Term']].mean().sort_values(by='Loan_Amount_Term',ascending=True)
# Out:
#         Loan_Amount_Term
# Gender
# Male          339.665272
# Female        352.293578

# %%
loan.groupby('Gender')[['Loan_Amount_Term']].sum()
# Out:
#         Loan_Amount_Term
# Gender
# Female           38400.0
# Male            162360.0

# %%
df1=pd.DataFrame({'names':['rob','jenny','kim'],'age':[10,20,30]})
df2=pd.DataFrame({'names':['robby','jenny','cho'],'age':[20,35,30]})

print(df1,"\n",df2)
# Out:
#    names  age
# 0    rob   10
# 1  jenny   20
# 2    kim   30
#     names  age
# 0  robby   20
# 1  jenny   35
# 2    cho   30

# %%
pd.merge(left=df1,right=df2,on='names',how='inner')
# Out:
#    names  age_x  age_y
# 0  jenny     20     35

# %%
pd.merge(left=df1,right=df2,on='names',how='outer')
# Out:
#    names  age_x  age_y
# 0    cho    NaN   30.0
# 1  jenny   20.0   35.0
# 2    kim   30.0    NaN
# 3    rob   10.0    NaN
# 4  robby    NaN   20.0

# %%
pd.merge(left=df1,right=df2,on='age',how='outer')
# Out:
#   names_x  age names_y
# 0     rob   10     NaN
# 1   jenny   20   robby
# 2     kim   30     cho
# 3     NaN   35   jenny

# %%
pd.merge(left=df1,right=df2,on='age',how='inner')
# Out:
#   names_x  age names_y
# 0   jenny   20   robby
# 1     kim   30     cho

# %%
pd.merge(left=df1,right=df2,on='names',how='left')
# Out:
#    names  age_x  age_y
# 0    rob     10    NaN
# 1  jenny     20   35.0
# 2    kim     30    NaN

# %%
pd.merge(left=df1,right=df2,on='names',how='right')
# Out:
#    names  age_x  age_y
# 0  robby    NaN     20
# 1  jenny   20.0     35
# 2    cho    NaN     30

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cred=loan[loan['Credit_History']==1]
cred
# Out:
#           Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002    Male      No          0      Graduate            No
# LP001003    Male     Yes          1      Graduate            No
# LP001005    Male     Yes          0      Graduate           Yes
# LP001006    Male     Yes          0  Not Graduate            No
# LP001008    Male      No          0      Graduate            No
# ...          ...     ...        ...           ...           ...
# LP002974    Male     Yes          0      Graduate            No
# LP002978  Female      No          0      Graduate            No
# LP002979    Male     Yes         3+      Graduate            No
# LP002983    Male     Yes          1      Graduate            No
# LP002984    Male     Yes          2      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# ...

# %%
sns.barplot(x='Gender',y='ApplicantIncome',data=cred)
# Out:
# <Axes: xlabel='Gender', ylabel='ApplicantIncome'>

# %%
#matplotlib --> low level plotting
#import seaborn as sns--> high level

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import matplotlib.pyplot as plt
sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.xlabel('total bills')
plt.ylabel('tip')
plt.title('total bills and tip')
plt.show()

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
sns.scatterplot(x='total_bill',y='tip',hue='sex',size='size',sizes=[50,200],data=tips)
plt.xlabel('total bills')
plt.ylabel('tip')
plt.title('total bills and tip')
plt.show()
# Out:
# <ipython-input-79-a4e5cdf4e142>:2: UserWarning:
# The sizes list has fewer values (2) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(x='total_bill',y='tip',hue='sex',size='size',sizes=[50,200],data=tips)

# %%
sns.scatterplot(x='LoanAmount',y='ApplicantIncome',data=loan)
# Out:
# <Axes: xlabel='LoanAmount', ylabel='ApplicantIncome'>

# %%
fmri=sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(x='timepoint',y='signal',data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
from datetime import date
sns.lineplot(x='timepoint',y='signal',hue='event',style='region', markers=True, dashes=False, data=fmri)
plt.xlabel('timepoint')
plt.ylabel('Signal Intensity')
plt.title('Changes in signal Intensity over time')
plt.show()

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(x='class',y='fare',data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(x='class',y='fare',hue='sex',data=titanic)
plt.xlabel('class')
plt.ylabel('fare')
plt.title('Changes in class end fare time')
plt.show()

# %%
#box plot   ---> distribution of data
sns.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#pair plot
sns.pairplot(data=titanic)
plt.show()

# %%
sns.scatterplot(x='total_bill',y='tip',hue='day',data=tips)
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.title("Relationship between total bill and Tip")
plt.show()

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.color_palette('Set2')
# Out:
# [(0.4, 0.7607843137254902, 0.6470588235294118),
#  (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
#  (0.5529411764705883, 0.6274509803921569, 0.796078431372549),
#  (0.9058823529411765, 0.5411764705882353, 0.7647058823529411),
#  (0.6509803921568628, 0.8470588235294118, 0.32941176470588235),
#  (1.0, 0.8509803921568627, 0.1843137254901961),
#  (0.8980392156862745, 0.7686274509803922, 0.5803921568627451),
#  (0.7019607843137254, 0.7019607843137254, 0.7019607843137254)]

# %%
sns.scatterplot(x='total_bill',y='tip',hue='day',data=tips,palette='Set2')
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.title("Relationship between total bill and Tip")
plt.show()

# %%
sns.scatterplot(x='total_bill',y='tip',hue='day',data=tips,palette='Set2')
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.title("Relationship between total bill and Tip")
plt.show()

# %%
# annotation
diamonds=sns.load_dataset('diamonds')
sns.scatterplot(x='carat',y='price',data=diamonds)
plt.text(2,1800,"large, expensive Diamond", fontsize=12,color='red')
plt.text(3.5,500,"small, affordable Diamond", fontsize=12,color='pink')
plt.show()
